# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.18-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.34 (from langchain)
#   Downloading langchain_core-0.3.34-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6 (from langchain)
#   Downloading langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.8-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.38-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: requests<3,>=2 in d:\develop\langchain-study\venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in d:\develop\langchain-study\venv\lib\site-packages (from langchain) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.11.12-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting numpy<2,>=1.26.4 (from langchain)
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in d:\develop\langchain-study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached frozenlist-1.5.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached multidict-6.1.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading propcache-0.2.1-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.18.3-cp311-cp311-win_amd64.whl.metadata (71 kB)
#      ---------------------------------------- 0.0/71.4 kB ? eta -:--:--
#      ---------------------------------------- 71.4/71.4 kB 1.9 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.34->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\develop\langchain-study\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading orjson-3.10.15-cp311-cp311-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 2.2 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.27.2-cp311-cp311-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\develop\langchain-study\venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\develop\langchain-study\venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\develop\langchain-study\venv\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\develop\langchain-study\venv\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-3.1.1-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: anyio in d:\develop\langchain-study\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in d:\develop\langchain-study\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\develop\langchain-study\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\develop\langchain-study\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in d:\develop\langchain-study\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Downloading langchain-0.3.18-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    --------------------- ------------------ 0.5/1.0 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 12.8 MB/s eta 0:00:00
# Downloading aiohttp-3.11.12-cp311-cp311-win_amd64.whl (442 kB)
#    ---------------------------------------- 0.0/442.7 kB ? eta -:--:--
#    --------------------------------------- 442.7/442.7 kB 13.5 MB/s eta 0:00:00
# Downloading langchain_core-0.3.34-py3-none-any.whl (412 kB)
#    ---------------------------------------- 0.0/413.0 kB ? eta -:--:--
#    --------------------------------------- 413.0/413.0 kB 13.0 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Downloading langsmith-0.3.8-py3-none-any.whl (332 kB)
#    ---------------------------------------- 0.0/332.8 kB ? eta -:--:--
#    --------------------------------------- 332.8/332.8 kB 10.1 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp311-cp311-win_amd64.whl (2.0 MB)
# Downloading SQLAlchemy-2.0.38-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.1 MB 5.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/2.1 MB 3.7 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.1 MB 3.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.1 MB 3.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.1 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.4 MB/s eta 0:00:00
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached frozenlist-1.5.0-cp311-cp311-win_amd64.whl (51 kB)
# Using cached greenlet-3.1.1-cp311-cp311-win_amd64.whl (298 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached multidict-6.1.0-cp311-cp311-win_amd64.whl (28 kB)
# Downloading orjson-3.10.15-cp311-cp311-win_amd64.whl (133 kB)
#    ---------------------------------------- 0.0/133.6 kB ? eta -:--:--
#    ---------------------------------------- 133.6/133.6 kB 8.2 MB/s eta 0:00:00
# Downloading propcache-0.2.1-cp311-cp311-win_amd64.whl (44 kB)
#    ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#    ---------------------------------------- 44.4/44.4 kB 1.1 MB/s eta 0:00:00
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading yarl-1.18.3-cp311-cp311-win_amd64.whl (91 kB)
#    ---------------------------------------- 0.0/91.0 kB ? eta -:--:--
#    ---------------------------------------- 91.0/91.0 kB 5.0 MB/s eta 0:00:00
# Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl (495 kB)
#    ---------------------------------------- 0.0/495.4 kB ? eta -:--:--
#    --------------------------------------- 495.4/495.4 kB 15.7 MB/s eta 0:00:00
# Installing collected packages: zstandard, tenacity, pydantic-core, propcache, orjson, numpy, multidict, jsonpatch, greenlet, frozenlist, annotated-types, aiohappyeyeballs, yarl, SQLAlchemy, requests-toolbelt, pydantic, aiosignal, langsmith, aiohttp, langchain-core, langchain-text-splitters, langchain
# Successfully installed SQLAlchemy-2.0.38 aiohappyeyeballs-2.4.6 aiohttp-3.11.12 aiosignal-1.3.2 annotated-types-0.7.0 frozenlist-1.5.0 greenlet-3.1.1 jsonpatch-1.33 langchain-0.3.18 langchain-core-0.3.34 langchain-text-splitters-0.3.6 langsmith-0.3.8 multidict-6.1.0 numpy-1.26.4 orjson-3.10.15 propcache-0.2.1 pydantic-2.10.6 pydantic-core-2.27.2 requests-toolbelt-1.0.0 tenacity-9.0.0 yarl-1.18.3 zstandard-0.23.0
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# aiohappyeyeballs          2.4.6
# aiohttp                   3.11.12
# aiosignal                 1.3.2
# annotated-types           0.7.0
# anyio                     4.8.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     25.1.0
# babel                     2.17.0
# beautifulsoup4            4.13.3
# bleach                    6.2.0
# certifi                   2025.1.31
# cffi                      1.17.1
# charset-normalizer        3.4.1
# colorama                  0.4.6
# comm                      0.2.2
# debugpy                   1.8.12
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.1
# fqdn                      1.5.1
# frozenlist                1.5.0
# greenlet                  3.1.1
# h11                       0.14.0
# httpcore                  1.0.7
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.29.5
# ipython                   8.32.0
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.5
# json5                     0.10.0
# jsonpatch                 1.33
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2024.10.1
# jupyter_client            8.6.3
# jupyter_core              5.7.2
# jupyter-events            0.12.0
# jupyter-lsp               2.2.5
# jupyter_server            2.15.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.3.5
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# langchain                 0.3.18
# langchain-core            0.3.34
# langchain-text-splitters  0.3.6
# langsmith                 0.3.8
# MarkupSafe                3.0.2
# matplotlib-inline         0.1.7
# mistune                   3.1.1
# multidict                 6.1.0
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook_shim             0.2.4
# numpy                     1.26.4
# orjson                    3.10.15
# overrides                 7.7.0
# packaging                 24.2
# pandocfilters             1.5.1
# parso                     0.8.4
# pip                       24.0
# platformdirs              4.3.6
# prometheus_client         0.21.1
# prompt_toolkit            3.0.50
# propcache                 0.2.1
# psutil                    6.1.1
# pure_eval                 0.2.3
# pycparser                 2.22
# pydantic                  2.10.6
# pydantic_core             2.27.2
# Pygments                  2.19.1
# python-dateutil           2.9.0.post0
# python-json-logger        3.2.1
# pywin32                   308
# pywinpty                  2.0.15
# PyYAML                    6.0.2
# pyzmq                     26.2.1
# referencing               0.36.2
# requests                  2.32.3
# requests-toolbelt         1.0.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.22.3
# Send2Trash                1.8.3
# setuptools                65.5.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.6
# SQLAlchemy                2.0.38
# stack-data                0.6.3
# tenacity                  9.0.0
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.4.2
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20241206
# typing_extensions         4.12.2
# uri-template              1.3.0
# urllib3                   2.3.0
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# yarl                      1.18.3
# zstandard                 0.23.0
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -U langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-openai) (0.3.34)
# Collecting openai<2.0.0,>=1.58.1 (from langchain-openai)
#   Downloading openai-1.62.0-py3-none-any.whl.metadata (27 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Using cached tiktoken-0.8.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-openai) (0.3.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-openai) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-openai) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in d:\develop\langchain-study\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-openai) (2.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\develop\langchain-study\venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.8.0)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.58.1->langchain-openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\develop\langchain-study\venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.58.1->langchain-openai)
#   Downloading jiter-0.8.2-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in d:\develop\langchain-study\venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Collecting tqdm>4 (from openai<2.0.0,>=1.58.1->langchain-openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests>=2.26.0 in d:\develop\langchain-study\venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in d:\develop\langchain-study\venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain-openai) (3.10)
# Requirement already satisfied: certifi in d:\develop\langchain-study\venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in d:\develop\langchain-study\venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\develop\langchain-study\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\develop\langchain-study\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\develop\langchain-study\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.34->langchain-openai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\develop\langchain-study\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.34->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\develop\langchain-study\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.34->langchain-openai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\develop\langchain-study\venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.34->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\develop\langchain-study\venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.34->langchain-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\develop\langchain-study\venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\develop\langchain-study\venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.3.0)
# Requirement already satisfied: colorama in d:\develop\langchain-study\venv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.58.1->langchain-openai) (0.4.6)
# Downloading langchain_openai-0.3.5-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/55.0 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/55.0 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 55.0/55.0 kB 952.0 kB/s eta 0:00:00
# Downloading openai-1.62.0-py3-none-any.whl (464 kB)
#    ---------------------------------------- 0.0/464.8 kB ? eta -:--:--
#    --------------------------------------  460.8/464.8 kB 28.2 MB/s eta 0:00:01
#    ---------------------------------------- 464.8/464.8 kB 9.7 MB/s eta 0:00:00
# Using cached tiktoken-0.8.0-cp311-cp311-win_amd64.whl (884 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.8.2-cp311-cp311-win_amd64.whl (206 kB)
#    ---------------------------------------- 0.0/206.7 kB ? eta -:--:--
#    --------------------------------------- 206.7/206.7 kB 12.3 MB/s eta 0:00:00
# Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, jiter, distro, tiktoken, openai, langchain-openai
# Successfully installed distro-1.9.0 jiter-0.8.2 langchain-openai-0.3.5 openai-1.62.0 regex-2024.11.6 tiktoken-0.8.0 tqdm-4.67.1
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
import getpass
from langchain.chat_models import init_chat_model

# .env 파일에서 환경변수 로드
load_dotenv()

# 환경변수에서 API 키 가져오기
api_key = os.getenv("OPENAI_API_KEY")

# API 키가 없으면 사용자에게 입력 받기
if not api_key:
    api_key = getpass.getpass("Enter API key for: ")

# 환경변수로 설정
os.environ["OPENAI_API_KEY"] = api_key

# Groq 모델 초기화
model = init_chat_model("gpt-4o-mini", model_provider="openai")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from English into Korean"),
    HumanMessage("hi!"),
]

model.invoke(messages)
# Out:
# AIMessage(content='안녕하세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 20, 'total_tokens': 24, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_72ed7ab54c', 'finish_reason': 'stop', 'logprobs': None}, id='run-4c130efa-f1b0-4e66-94b7-38d720ed3e06-0', usage_metadata={'input_tokens': 20, 'output_tokens': 4, 'total_tokens': 24, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
